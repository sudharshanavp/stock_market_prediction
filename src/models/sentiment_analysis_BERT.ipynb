# %%
from transformers import BertTokenizer, BertForSequenceClassification
import numpy as np

# %%
import pandas as pd

# %%
import torch

# %%
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

# %%
news_list = pd.read_csv("../../data/raw/news/ADANIPORTS.csv")["Headlines"]

# %%
news_list.to_list()
# Out:
# ['Adani Ports & SEZ: More fuel left for its acquisition-led growth',
#  'Adani Ports Consolidated March 2022 Net Sales at Rs 3,845.03 crore, up 6.57% Y-o-Y',
#  'Adani Ports Standalone March 2022 Net Sales at Rs 1,057.78 crore, down 11.28% Y-o-Y',
#  'Trade Spotlight | What should you do with JSW Energy, Cholamandalam Investment, Apollo Tyres, NLC India, Adani Ports today?',
#  'Top 10 trading ideas by experts in a range bound market for next 3-4 weeks',
#  'Explained | Why is Adani buying 100% stake in Ocean Sparkle',
#  'Adani Ports acquires 100% stake in Ocean Sparkle',
#  'Indian ports fast-track efforts to increase cargo handling capacity',
#  'Adani Ports targets cargo volumes of 500 MMT by 2025',
#  "Norway wealth fund puts India's Adani Ports, other companies on watch list",
#  'Adani Ports Consolidated December 2021 Net Sales at Rs 3,797.10 crore, up 1.35% Y-o-Y',
#  'Adani Ports Standalone December 2021 Net Sales at Rs 1,078.51 crore, down 17.37% Y-o-Y',
#  'Mundra Drug Seizure | DRI records Adani Ports statement under NDPS Act',
#  'Adani Ports Standalone September 2021 Net Sales at Rs 1,090.02 crore, up 0.74% Y-o-Y',
#  'Ideas For Profit | Adani Ports & SEZ: how Concor acquisition can lead to stock re-rating',
#  'Adani Ports Consolidated September 2021 Net Sales at Rs 3,532.42 crore, up 21.7% Y-o-Y',
#  'Adani Ports Standalone September 2021 Net Sales at Rs 1,090.02 crore, up 0.74% Y-o-Y',
#  'Adani Ports planning to exit its investment in Myanmar by June 2022',
#  'Adani Ports gets CCI approval for acquisition of 10.4% stake in Gangavaram Port',
#  'Adani Ports gets approval to buy 10.4% stake in Gangavaram Port',
#  'Ideas For Profit | Adani Port & SEZ',
#  'Bajar Gupshup | Nifty ends above 16,250; financials lead gains',
#  'What should investors do with Adani Ports after June quarter results: buy, sell or hold?',
#  'Investment in Myanmar port not in violation of US sanctions: Adani Ports',
#  'Adani Ports Consolidated June 2021 Net Sales at Rs 4,556.81 crore, up 98.75% Y-o-Y',
#  'Adani Ports Standalone June 2021 Net Sales at Rs 1,210.82 crore, up 51.79% Y-o-Y',
#  'Adani Ports Q1 profit jumps 77 percent to Rs 1,342 crore',
#  'Adani Ports raises $750 million from global markets',
#  'Adani Group stocks hit lower circuit over Sebi, DRI investigation',
#  'Bajar Gupshup | Nifty ends below 15,700; bank and IT stocks drag',
#  'Hello World | India’s tech IPOs, debt and frugality',
#  'Norway’s pension fund KPL divests from Adani Ports over links to Myanmar military',
#  "Adani Ports shares erase morning gains to end in red; global brokerage retains 'buy'",
#  'CCI okays acquisition of additional 25% shareholding of Krishnapatnam Port by Adani Ports',
#  'Adani Ports Consolidated March 2021 Net Sales at Rs 3,607.90 crore, up 23.51% Y-o-Y',
#  'Adani Ports Standalone March 2021 Net Sales at Rs 1,192.29 crore, up 0.61% Y-o-Y',
#  'Exclusive | Adani Ports’ acquisition of Gangavaram Port hits stumbling block',
#  'Adani Ports waives charges for ships carrying COVID equipment, gives priority berthing',
#  'CCI approves acquisition of Gangavaram Port Limited by Adani Ports and Special Economic Zones',
#  'Adani Ports removed from S&P index due to links with Myanmar military',
#  'Adani Ports to acquire remaining 25% stake in Krishnapatnam Port, shares fall',
#  'Explained | How Adani Ports is getting ready to become India’s largest private operator',
#  'Acquisition of\xa0Gangavaram\xa0Port adds strength to Adani Ports\xa0',
#  'Adani Ports shares continue to gain after acquiring controlling stake in Gangavaram Port',
#  "Pimco's unwillingness to invest in Adani to have no impact\xa0",
#  'Adani Ports to acquire controlling stake in Gangavaram Port for Rs 3,604 crore',
#  'Adani Ports share price gains 2% on deal with Sri Lankan government',
#  'Adani Ports-led consortium gets LoI from Sri Lanka govt to build West Container Terminal at Colombo Port',
#  'Warburg Pincus arm to invest Rs 800 crore for 0.49% stake in Adani Ports',
#  'Adani Ports acquires 31.5% stake in\xa0Gangavaram Port for Rs 1,954 crore',
#  'What should investors do with Adani Ports post Q3: Buy, sell or hold?',
#  'Adani Ports Consolidated December 2020 Net Sales at Rs 3,746.49 crore, up 12.3% Y-o-Y',
#  'Adani Ports Standalone December 2020 Net Sales at Rs 1,305.18 crore, up 10.35% Y-o-Y',
#  'Adani ports Q3 preview | Healthy numbers expected; pick up in cargo volumes to support growth',
#  'Adani Ports share price hits 52-week high after cargo volume growth rises 10% YoY',
#  'Adani Ports Consolidated September 2020 Net Sales at Rs 2,902.52 crore, up 2.88% Y-o-Y',
#  'Adani Ports share price gains on Q2 profit; HSBC, CLSA, Nomura retain buy',
#  'New port acquisition, volume recovery put Adani Ports firmly on growth path',
#  'Gainers & Losers: 10 stocks that moved the most on October 6',
#  'Adani Ports share price rises 3%; here is what brokerages have to say about Krishnapatnam Port acquisition',
#  'Principle of Polarity suggests buying opportunity in Adani Ports: Shabbir Kayyumi',
#  'Mundra Port terminal deal under scrutiny over link with Chinese company: Report',
#  "Adani Ports, GVK Power shares jump 4% on AAHL's plans to acquire GVK Airport's debt",
#  'Adani Enterprises share price surges 24% on reports of group eyeing 74% stake in MIAL',
#  'Adani Ports Consolidated June 2020 Net Sales at Rs 2,292.69 crore, down 17.96% Y-o-Y',
#  'Adani Ports Standalone June 2020 Net Sales at Rs 797.72 crore, down 33.76% Y-o-Y',
#  'Adani Ports shares rise 3% post Q1 result; brokerages maintain buy',
#  'Adani Ports & SEZ raises $750 million via bond issue',
#  'Adani Ports raises Rs 100 crore through NCDs',
#  'Adani Ports Consolidated March 2020 Net Sales at Rs 2,921.19 crore, down 5.23% Y-o-Y',
#  'Adani Ports Consolidated March 2020 Net Sales at Rs 2,921.19 crore, down 5.23% Y-o-Y',
#  'Adani Ports share price rises 3% post weak Q4 result; Morgan Stanley remains overweight',
#  'Adani Ports Consolidated March 2020 Net Sales at Rs 2,921.19 crore, down 5.23% Y-o-Y',
#  'Adani Ports Consolidated December 2019 Net Sales at Rs 3,336.25 crore, up 18.14% Y-o-Y',
#  'Adani Ports & SEZ: Diversification brings home growth',
#  'Adani Ports Standalone December 2019 Net Sales at Rs 1,182.76 crore, down 18.86% Y-o-Y',
#  'Adani Ports Consolidated December 2019 Net Sales at Rs 3,336.25 crore, up 18.14% Y-o-Y',
#  'Market Headstart: Nifty set to scale levels above 12,400 levels in Jan series',
#  'What MFs bought & sold in Nov; 60 names from large, mid & smallcap space',
#  'Terror alert: Security beefed up at Kandla, Mundra ports',
#  'Adani Ports Consolidated June 2019 Net Sales at Rs 2,794.47 crore, up 15.9% Y-o-Y',
#  'Adani Ports Standalone June 2019 Net Sales at Rs 1,204.33 crore, up 11.39% Y-o-Y',
#  'Adani Ports Consolidated March 2019 Net Sales at Rs 3,082.49 crore, down 3.15% Y-o-Y',
#  'Adani Ports Standalone March 2019 Net Sales at Rs 1,594.28 crore, down 18% Y-o-Y',
#  "Adani Ports and SEZ's acquisition of Agri Logistics: More than meets the eye",
#  'Adani Ports Consolidated December 2018 Net Sales at Rs 2,823.91 crore, up 5.02% Y-o-Y',
#  'Adani Ports Standalone December 2018 Net Sales at Rs 1,457.60 crore, up 2.84% Y-o-Y',
#  'Nifty could fall further and move towards 10,500 in coming days: Centrum Broking',
#  'December expiry: 10 short-term money making ideas for last week of 2018',
#  'Here is why Kotak prefers Adani Ports, Gujarat Pipavav Port over Container Corp',
#  'Market week ahead: Expiry, GDP & state elections among 10 factors to watch out for',
#  'Adani Ports Consolidated September 2018 Net Sales at Rs 2,608.01 crore, Down 3.63% Y-o-Y.',
#  'Adani Ports & SEZ: On a strong growth trajectory',
#  'Adani Ports Standalone September 2018 Net Sales at Rs 1,203.27 crore, down 21.19% Q-o-Q',
#  'After deep cuts seen on Dalal Street, you can buy these 12 value picks for double-digit returns',
#  'Markets Head Start: Nifty likely to open lower; 3 stocks which could give 7-10%',
#  'Podcast | Stock picks of the day: Nifty likely to consolidate; 3 stocks which could give 7-10% return',
#  'KKR, Blackstone & Aion envisage interest in Dighi Port: Report',
#  'Market Update: FMCG stocks trade weak as ITC, Emami fall 2-3%; Sun Pharma top loser, PC Jeweller up 21%',
#  'Market Update: IT, Pharma index outperforms led by TCS, Glenmark; Adani Ports up 3%; SBI most active',
#  'Market Update: Midcap index outperforms led by TVS Motor; Adani Ports top gainer, Escorts at new 52-week high',
#  'Buy Bajaj Finance, Jubilant Foodworks, Avenue Supermarts, Ashok Leyland: Ashwani Gujral',
#  'Sell Adani Ports, Sun TV Network; buy Suprajit Engineering, Avenue Supermarts, Bajaj Finance, Jubilant Foodworks: Ashwani Gujral',
#  'Short Adani Ports, says Mitessh Thakkar',
#  'Market Update: CNX metal down over 1% dragged by Tata Steel & SAIL; SBI, HDFC most active',
#  'Market Update: PSU bank index falls 1% dragged by Allahabad Bank, SBI; Vedanta, Airtel top gainers',
#  'Market Update: RIL, SBI, ICICI Bank top Nifty gainers; Trent jumps 5%, LIC Housing Lupin hit 52-week low',
#  'Sell Adani Ports, Pidilite Industries, Bajaj Finance, CESC: Mitessh Thakkar',
#  'Sell Karnataka Bank, Adani Ports; buy Ashok Leyland, NIIT Tech: Sandeep Wagle',
#  'Market Update: 170 stocks hit new 52-week low as Nifty PSU bank plunges over 3%; SBI top loser',
#  'Buy Persistent Systems, Sun Pharma, Adani Ports, Bajaj Finance, JSPL, NIIT Technologies: Ashwani Gujral',
#  'Buy Adani Ports; sell Axis Bank, Union Bank of India: Ashwani Gujral',
#  'Sell Adani Ports, Bhushan Steel; buy Ashok Leyland: Mitessh Thakkar',
#  'Buy Voltas; sell Grasim Industries, Adani Ports: Rajat Bose',
#  'Market Update: PNB up 1% as PSU banks outperform, Tata Steel most active; Quess Coorp, Havells down 4%',
#  'Buy ITC, Hero MotoCorp; sell Wockhardt, Adani Ports: Rajat Bose',
#  'Buy PNB, UPL, Union Bank of India, Punjab National Bank, ONGC, Exide Industries: Ashwani Gujral',
#  'Market Update: HDFC twins top Nifty gainers, hit new 52-week high; ONGC jumps 5%, JP Associates zooms 10%',
#  'Market Update: Adani Ports, Yes Bank jumps 2%; TCS hits new 52-week high, Bharti Airtel most active',
#  'Pick Axis Bank, SBI, V-Guard Industries, UPL, Adani Ports: Amit Gupta',
#  'Buy GMR Infra, Adani Ports: Sandeep Wagle',
#  'Buy Jaiprakash Associates, Vedanta, United Breweries: Ashwani Gujral',
#  'Market Update: CNX IT outperforms as Infosys, TCS hit new 52-week high; RIL, ICICI Bank most active',
#  'Buy Adani Ports, Colgate Palmolive, Indiabulls Housing Finance; hold L&T Infotech, TCS: Sudarshan Sukhani',
#  "Adani Ports dredging fleet emerges as India's largest: APSEZ",
#  'Market update: Midcaps outshine Nifty led by Biocon; Delta Corp jumps over 7%',
#  'Sell ICICI Bank, Adani Ports; buy United Spirits: Ashwani Gujral',
#  'Buy Adani Ports, Jubilant Foodworks, hold Biocon; sell Exide Industries: Sudarshan Sukhani',
#  'Sell Adani Ports, NTPC: Sandeep Wagle',
#  'Sell Adani Ports; buy BPCL, Apollo Hospitals: Ashwani Gujral',
#  'Buy Adani Ports, Ashok Leyland, HPCL, Bata; short Idea Cellular: Sudarshan Sukhani',
#  'Sell Adani Ports, buy Titan Company: Sandeep Wagle',
#  'Buy Godrej Consumer, Bata India; sell Adani Ports: Ashwani Gujral',
#  'Largecap makes a comeback! 9 Sensex stocks which hit record highs in July rose up to 17%',
#  'Buy TVS Motor, Adani Ports, Hindalco Industries: Rajat Bose',
#  'Buy Union Bank of India, Power Grid, Bosch, Adani Ports: Amit Gupta',
#  'Buy Manappuram Fin, Chambal Fert, Ashok Leyland, M&amp;M Fin, Adani Ports: Gujral',
#  'Buy Adani Ports, Allahabad Bank: Sandeep Wagle',
#  'Buy Bharat Forge, Century Tex; sell JSW Energy, Godfrey Phillips: Mitessh Thakkar',
#  'Resistance for Nifty at 9969; buy Apollo Tyres, Adani Ports, DHFL: Prakash Gaba',
#  'Adani Ports can climb to Rs 385, Indian Bank Rs 330: Prakash Gaba',
#  'Buy Biocon, Aurobindo Pharma on every dip; sell Axis Bank, Adani Ports: Ashwani Gujral',
#  'Buy Adani Ports, Glenmark, Godrej Consumer; sell Dish TV: Sudarshan Sukhani',
#  'Buy Adani Ports, United Breweries: Sandeep Wagle',
#  'Buy HDFC, Adani Ports, Indiabulls Housing: Ashwani Gujral',
#  'Buy Adani Ports, Britannia Industries; sell Amara Raja Batteries: Sudarshan Sukhani',
#  'Buy Apollo Tyres, Ceat, Adani Ports, Bharti Infratel, Maruti Suzuki: Mitessh Thakkar',
#  'Buy Voltas, Ceat, Adani Ports, hold Maruti Suzuki; avoid Infosys: Sudarshan Sukhani',
#  'A move above 9,720 will strengthen bullish move; 5 stocks to buy on Tuesday',
#  'Buy Adani Ports, NBCC; sell Biocon, Voltas: Mitessh Thakkar',
#  'Buy Reliance Industries, Adani Ports: Sudarshan Sukhani',
#  'Adani Ports rises 3% as Moody’s revises outlook to stable from negative',
#  'Buy Interglobe Aviation, Adani Ports; DLF may test Rs 200: Mitessh Thakkar',
#  'Buy Power Grid, Adani Ports: Amit Gupta',
#  'Nifty may face resistance at 9724; 4 stocks to bet on today',
#  'Above Rs 340, Adani Ports may hit Rs 370, stay with housing finance: Gujral',
#  'Nifty likely to hit 9700-9720 soon; 5 stocks which can return up to 5% this week',
#  'Buy IRB Infra, Adani Ports: Mitessh Thakkar',
#  'Buy Adani Ports, Bata; Titan may test Rs 580, Bajaj Auto Rs 3020: Mitessh Thakkar',
#  "Bull's Eye: Buy Colgate, NMDC, DCB Bank, Balmer Lawrie, Godfrey Phillips",
#  'Six in Sixty: Stocks you should keep on your radar',
#  'Buy UPL, Mahindra & Mahindra Financial, Adani Ports: Ashwani Gujral',
#  'Six in Sixty: Stocks you should keep on your radar',
#  'Adani Ports’ Q4 net rises 29% to Rs 1,164 crore, EBITDA margin up at 69.1%',
#  'Stocks in the news: Lupin, Tata Steel, Videocon, NCC, Voltas, Cerebra Integrated',
#  'Buy Container Corporation of India, sell Adani Ports: Sandeep Wagle',
#  'Buy Adani Ports, DCB Bank, Bank of Baroda; sell Interglobe, Arvind: Ashwani Gujral',
#  'Strong support available at 9,250 for Nifty; 5 stocks to buy which could give up to 12% upside',
#  "Infosys, Torrent, Adani Ports, Hindalco among top 8 stocks on IDFC Securities' shopping list",
#  'Buy Adani Ports, ACC, Indiabulls Housing Finance: Ashwani Gujral',
#  'Buy Adani Ports, sell Zee Entertainment: Sandeep Wagle',
#  'Resistance for Nifty at 9414; buy SBI, Voltas, Adani Ports: Prakash Gaba',
#  'Buy Grasim Industries, Adani Ports: Mitessh Thakkar',
#  'Stocks in the news: Wipro, Adani Ports, LIC Housing, Nucleus, Visa Steel, Vascon',
#  'Buy Aditya Birla Nuvo, Adani Ports, Rural Electrification Corporation; sell Mahindra and Mahindra, Apollo Hospitals: Sudarshan Sukhani',
#  'Buy Reliance Infra, OBC, Reliance Capital: Ashwani Gujral',
#  'Six in Sixty: Stocks you should keep on your radar',
#  'Buy Hindalco Industries, Vedanta, Adani Ports: Ashwani Gujral',
#  'Buy Petronet LNG, Adani Enterprises, Tata Sponge: Ashwani Gujral',
#  'Six in Sixty: Stocks you should keep on your radar',
#  'Buy Ceat, Karur Vysya Bank, Muthoot Finance: Ashwani Gujral',
#  'Sell UBL, Bharat Financial; buy Adani Ports, Petronet, Piramal Ent: Sukhani',
#  'Buy Capital First, Adani Ports, Uflex: Ashwani Gujral',
#  'Goldman downgrades Adani Ports to neutral, sees no imminent catalysts near term',
#  'Buy Adani Ports 340 Call, sell 360 Call: Krish Subramamnyam',
#  'Top buzzing midcap stocks to trade on April 7',
#  'Buy HPCL, Larsen and Toubro, Capital First: Ashwani Gujral',
#  "Buy, sell, hold: 12 stocks & 2 sectors on analysts' radar as market at record high",
#  'Here are some trading ideas from SP Tulsian',
#  'Six in Sixty: Stocks you should keep on your radar',
#  'APM Terminals looking to exit Gujarat Pipavav Port: Sources',
#  'Nifty, Bank end March series at record closing high; HDFC Bank lifts Sensex 116 pts',
#  'Buy Indiabulls Real Estate, Adani Ports, Sintex Industries: Mitessh Thakkar',
#  'Buy Indiabulls Real Estate, Adani Ports, Century Plyboards; banks to take market higher: Ashwani Gujral',
#  'Sell Bharat Forge, GAIL India, Canara Bank; buy Hindustan Unilever, Adani Ports: Sudarshan Sukhani',
#  'Create fresh long once Nifty closes above 9,160; 5 five stocks to buy based on technical parameters',
#  'ICRA upgrades rating outlook of APSEZ to stable',
#  'Nifty struggles below 8800; Sun Pharma loses 3%, Adani Ports up',
#  'Sensex, Nifty volatile; Grasim, Tech Mah, Adani Ports rally 2-3%',
#  'Nifty nears 8450, Sensex climbs over 100 pts; Infosys, ITC fall',
#  'Buying continues on Dalal Street; Axis Bank falls 1% ahead of Q3',
#  'Nifty still above 8250; auto, FMCG, metals lend support',
#  'Sensex rises over 200 pts, Nifty strong; TCS, M&M, Infosys drag',
#  'Sensex, Nifty continue to rise; ITC up 3%, Lupin & Cipla gainers',
#  'Sensex falls 1%, Nifty ends at 7979; ITC, Tata Motors outperform',
#  'Nifty opens above 8250, Sensex rises; Adani, Hero, Maruti gain',
#  'Sensex, Nifty firm as investors await RBI policy; TCS, ITC drag',
#  'Sensex, Nifty steady; HDFC up 3%, Sun Pharma & Hero down',
#  'Nifty opens above 8150, Sensex up over 100 pts; HDFC, GAIL gain',
#  'Nifty hovers around 8100, Sensex unsteady;banks fall on RBI move',
#  'Sensex, Nifty bleed in late trade;Midcaps at biggest 1-day close',
#  'Nifty hits 8550, Sensex rises over 350 pts; Sun Pharma up 3%',
#  'Midcap index crashes 5% on black money crackdown',
#  'Sensex cracks 900 pts; Trump needs 26 electoral votes to win',
#  'Nifty hovers around 8500, Sensex flat; Sun Pharma, Maruti down',
#  'Sensex gains over 100pts, Nifty eyes 8550; ICICI, Tata Motors up',
#  'Adani Ports to deleverage further: Fitch',
#  'Muhurat special: Nifty ends below 8650, Sensex in red; Lupin up',
#  'Nifty hits 8600, Sensex soars over 300 pts; pharma, infra gain',
#  'Nifty hits 8600, Sensex steady; TCS, Reliance, L&T support',
#  'Sensex cracks over 400 pts, Nifty below 8600; J&K Bank tanks 17%',
#  'Nifty opens above 8750, Sensex climbs over 100 pts; Adani gains',
#  'Sensex, Nifty rise over 1%; autos, banks, oil stocks support',
#  'Nifty hovers around 8600, Sensex flat; BHEL, SBI, Infosys gain',
#  "Green tribunal clears Adani Ports' deep sea port",
#  'Six in Sixty: Stocks you should keep on your radar',
#  'Sensex reclaims 28000, Nifty firm; TCS falls 1% post Q1 nos',
#  'Market at 10-mth closing high, Nifty ends above 8550; banks lead',
#  'Sensex, Nifty in red; BHEL up 4%, Indiabulls plunges on I-T raid',
#  'Sensex, Midcap hold morning gains; ONGC, Adani Ports, BHEL up 4%',
#  'Nifty reclaims 8150, Sensex recovers; IT stocks up, SBI falls 1%',
#  'Sensex, Nifty firm; capital goods, oil, auto stocks lead rally',
#  'Nifty ends tad above 8100, Sensex flat; IT slips, SBI up 3%',
#  "'APSEZ to complete Vizhinjam Int port in scheduled time'",
#  'Nifty ends at 8273, Sensex flat; BHEL gains 2%, Infosys loses 2%',
#  'Sensex, Nifty open flat; Infosys, Adani Ports, M&M gainers',
#  'Nifty ends below 8200, Sensex steady; SBI, Tata Motors laggards',
#  'Sensex up over 300 pts, Nifty opens above 7800; banks strong',
#  'Sensex, Nifty rangebound; TCS, SBI, Sun Pharma laggards',
#  'Sensex, Nifty continue to rise; Sun TV jumps 10%, HUL down',
#  'Nifty still below 7850, Sensex wobbles; Bharti, HUL laggards',
#  'Sensex, Nifty wobbles; GAIL rises 2%, Adani Ports down 2%',
#  'Nifty ends below 7750, Sensex gains 160 pts; infra, FMCG  gain',
#  'Sensex, Nifty continue to rise; HDFC, BHEL rally 3-4%',
#  'Sensex, Nifty flat; Adani Ports tanks 10%, Hero gains 1%',
#  'Sensex zooms over 200pts, Nifty above 7850; Tata Motors, HDFC up',
#  'Sensex, Nifty sluggish; Maruti, GAIL, Cipla top gainers',
#  'Market recovers sligthly but Sensex, Nifty still weak; metals up',
#  'Sensex, Nifty end at 2016 closing high; banks drag, FMCG soar',
#  'Nifty reclaims 7900, Sensex gains 200 pts; bank, auto lead',
#  'Sensex, Nifty continue to fall; Maruti, Hindalco dip 2-3%',
#  'Nifty hovers around 7900, Sensex flat; Bajaj Auto rises 2%',
#  'Nifty hits 7700, Sensex rises; Hero & DRL up, Tata Steel falls',
#  'Sensex, Nifty end flat; metals shine, banks fall further',
#  'Nifty holds 7700 amid pressure; ITC, Adani Ports, Bharti losers',
#  'Nifty opens above 7500, Sensex firm; Lupin falls, Bharti gains',
#  'Nifty ends at 7510, Sensex up 95 pts; Lupin, HUL, ITC gain 2%',
#  'Nifty eyes 7550, Sensex up over 150 pts; ITC, Maruti gainers',
#  'Nifty holds 7500, Sensex stable; oil & metal stocks lend support',
#  'Sensex rises 464 pts, Nifty ends above 7350; SBI surges 12%',
#  'Nifty soars 500 pts, Sensex up 1650 pts from Budget lows',
#  'Sensex, Nifty sluggish; market anxious ahead of Rail Budget',
#  'Nifty hovers around 7000, Sensex weak; BHEL up 1%, ICICI down 4%',
#  'Stocks in news: Bank Of India, Valecha Engg, BPCL, IOB',
#  'Sensex sheds 362 pts, Nifty ends below 7050; SBI falls 6%',
#  'Sensex loses 100 pts, Nifty below 7150; HDFC twins, L&T down',
#  'Nifty above 7100, Sensex above 350 pts; BoB zooms 15%',
#  'Bear rampage continues, Sensex & Nifty wobbly; Auto index up',
#  'Nifty cracks below 7100, Sensex tanks over 450 pts; SBI down 1%',
#  'Nifty ends below 7250, Sensex at 21-month low; SBI tanks 5%',
#  'Nifty ends above 7400, short covering lifts Sensex; metals gain',
#  'Sensex continues to climb, Nifty firm; Tata Steel down, ONGC up',
#  'Nifty opens above 7550 ahead of RBI policy; Sun Pharma up 1%',
#  'Sensex, Nifty flat; Maruti & ITC big gainers, BHEL down',
#  'Sensex, Nifty volatile; Infosys extends gains, banks weak',
#  'Sensex, Nifty tumble 1%; Cap Goods & Small Cap tank 4%',
#  'Sensex, Nifty remain under pressure; Axis, ONGC, Infosys drag',
#  'Sensex, Nifty rangebound; TCS & Wipro down 1-3% ahead of Q3 nos',
#  'Nifty below 7500, Sensex sinks over 300 pts; Tata Motors tanks',
#  'Buy Adani Ports; target of Rs 334: Edelweiss',
#  'Nifty ends tad below 7850, Sensex flat; ITC, Hindalco fall',
#  'Buy Adani Ports; target of Rs 351:Edelweiss',
#  "Stocks in news: Dr Reddy's Lab, DLF, NMDC, Adani Ports",
#  'Budget 2015-16: An Analysis by Hem Securities',
#  "Adani's Aus coal mine project hit by ownership controversy",
#  'Nifty volatile; Aban Offshore, Adani Ports, RIL most active',
#  '2014 belongs to cement, logistics: Prakash Diwan',
#  'Buy Ambuja Cements, BPCL; sell Jindal Steel: SP Tulsian',
#  'Buy Maruti Suzuki India: Sudarshan Sukhani',
#  'Adani Ports may move to Rs 163-164: SP Tulsian',
#  'Buy L&T, Tech Mahindra, Crompton Greaves: Meghana Malkan',
#  'Adani Enterprises Q2 PAT seen down at Rs 60 cr vs Rs 320 cr',
#  'Adani Ports Q2 net up 24% at Rs 342 cr',
#  "Adani Ports consolidated Sep '13 sales at Rs 1,149.88 crore",
#  "Bull's Eye: Colgate, Reliance Power, Adani Ent, DLF",
#  'Why clearance of LARR Bill is important?',
#  "Bull's Eye: Buy Titan, HDIL; sell Adani Port, Tata Chemical",
#  'Adani Ports seeks fresh approval for SEZ at Mundra',
#  "Bull's Eye: Buy Hexaware, Wockhardt; short Financial Tech",
#  'Stocks in news: Guj Gas, Tilaknagar, Eicher Motors, Ranbaxy',
#  'Adanis close to acquiring Dhamra Port',
#  "Bull's Eye: Buy Biocon, Titan, Dabur; short Canara Bank",
#  'Buy Adani Ports; target Rs 170: Emkay',
#  'Sebi revokes restrictions against two firms',
#  'Stocks in news: ACC, RComm, IOC, Jet, Hindustan Copper',
#  'Buy IndusInd Bank, Madras Cements; sell YES Bank: Experts',
#  'Go long in Adani Ports, Bata India, says Ashish Kapur',
#  "Bull's Eye: Buy Karnataka Bank, Adani Ports; short Sintex",
#  'Check out: Top super six ideas for the day',
#  'Time to nibble; bet on IT, auto, FMCG, pharma: Edelweiss',
#  'Sell Adani group stocks, says Sudarshan Sukhani',
#  'Sukhani sees 5750 as strong support, suggests buys',
#  'Buy Adani Ports; target of Rs 174: KRChoksey',
#  'Focus on Nifty & IT; ignore banks: Sukhani',
#  "Bull's eye: Buy JM Financial, Adani Ports, Sun TV, Emami",
#  'Adani Ports Q4 net profit triples to Rs 710.31 cr',
#  'Adani Ports spurts after Q4 net triples to Rs 710.31 cr',
#  'Adani Ports Q4 PAT up at Rs 710cr',
#  'Adani Ports looks best among Adani Group: Sukhani',
#  'Short Adani Ports, says Sukhani',
#  'Adani Power, Adani Ent fall for 5th consecutive day',
#  'Market likely to see relief rally anytime, says Sukhani',
#  'HDFC MF buys IT, oil & gas; sells engineering, auto',
#  'DSP BlackRock MF sells banking, auto; buys IT, telecom',
#  "Adani Ports consolidated Dec '12 sales at Rs 1,349.90 crore",
#  'Buy Adani Ports; target of Rs 171: KRChoksey',
#  "Bull's eye: Buy Essar Oil, Welspun Corp; short Adani Power",
#  'Buy Adani Ports, NHPC; sell Rel Comm, Unitech: Parag Doctor',
#  "Bull's eye: Buy NHPC, Pidilite; short Idea, IVRCL",
#  'Buy Adani Ports on correction: Sukhani',
#  'Adani Port surges on Abbott stake sale plan',
#  'Stocks in news: Kingfisher, Adani Ports, Orient Refra, DCHL',
#  'Shipping stocks gain eyeing Rs 11Kcr new govt orders',
#  'Adani Ports will do well, says Suresh Mahadevan',
#  "Don't trade Nifty before RBI policy: Sudarshan Sukhani",
#  'Nifty may test 6005-6180: R K Global',
#  'Buy Adani Ports; target of Rs 150: Emkay',
#  'Stocks in news: Amar Remedies, HCL Tech, Suzlon, NTPC',
#  "Bull's eye: Buy HPCL, Sun TV; short CESC, Adani Ports",
#  'Buy DEN Networks, BF Utilities, Sun TV: Kapur',
#  "Bull's eye: Buy Bharti, Sun TV, short Tata Motors, BHEL",
#  'Infrastructure stocks hit by port report',
#  'Stocks in news: Rohit Ferro, DCHL, SKS, Adani Ports, L&T',
#  'Sudarshan Sukhani sees no trade in Nifty; all PSBs weak',
#  'Stocks in news: Adani Ports, Hind Zinc, ITI, JP Associates',
#  'Sukhani upbeat on Sun Pharma',
#  'Expect choppy trade; look to exit long positions: Sukhani',
#  'Buy Adani Ports & SEZ; target Rs 145: KRChoksey',
#  'Tata Mutual Fund picks engineering, auto; sells IT, oil&gas',
#  "Sukhani's view on Adani Ports",
#  'Close long positions if Nifty ends below 5300: Sukhani',
#  'Adani Ports to build &#36;216 mn terminal in Gujarat',
#  "Nifty's aim of 5100 intact; protect your positions: Sukhani",
#  "Adani Ports Mar '12 sales at Rs 641.88 crore",
#  'Mkt to see mild recovery; bullish bias for today: Sukhani',
#  'Pick Adani Ports over BHEL: Morgan Stanley',
#  'Adani Ports has target of Rs 145: LKP',
#  'Buy Adani Ports; target of Rs 160: Prabhudas Lilladher',
#  'Adani raises &#36;1.25 bn refinancing loan: Sources',
#  "Don't see Nifty holding 5200; take short positions: Sukhani",
#  'Buy Central Bank; sell Adani Ports on rallies: GEPL Capital',
#  "Sukhani's view on Exide Industries",
#  'Accumulate Adani Ports; target of Rs 161: PLilladher',
#  'Short Adani Ports, says Devangshu Datta']

# %%
sentences = ["there is a shortage of capital, and we need extra financing", 
             "growth is strong and we have plenty of liquidity", 
             "there are doubts about our finances", 
             "profits are flat"]

inputs = tokenizer(sentences, return_tensors="pt", padding=True)
outputs = finbert(**inputs)[0]

labels = {0:'neutral', 1:'positive',2:'negative'}
for idx, sent in enumerate(sentences):
    print(sent, '----', labels[np.argmax(outputs.detach().numpy()[idx])])
# Out:
# A ---- positive
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/turner/repos/stock_market_prediction/src/models/sentiment_analysis_BERT.ipynb Cell 7' in <cell line: 7>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/turner/repos/stock_market_prediction/src/models/sentiment_analysis_BERT.ipynb#ch0000003vscode-remote?line=5'>6</a> labels = {0:'neutral', 1:'positive',2:'negative'}
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/turner/repos/stock_market_prediction/src/models/sentiment_analysis_BERT.ipynb#ch0000003vscode-remote?line=6'>7</a> for idx, sent in enumerate(sentences):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/turner/repos/stock_market_prediction/src/models/sentiment_analysis_BERT.ipynb#ch0000003vscode-remote?line=7'>8</a>     print(sent, '----', labels[np.argmax(outputs.detach().numpy()[idx])])
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
